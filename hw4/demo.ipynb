# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2 
import graph_model

# %%
image1 = cv2.imread("imgs/image_01.png")
image2 = cv2.imread("imgs/image_02.png")
image3 = cv2.imread("imgs/image_03.png")
image4 = cv2.imread("imgs/image_04.png")
image5 = cv2.imread("imgs/image_05.png")
mask1 = cv2.imread("imgs/mask_01.png")
mask2 = cv2.imread("imgs/mask_02.png")
mask3 = cv2.imread("imgs/mask_03.png")
mask4 = cv2.imread("imgs/mask_04.png")
mask5 = cv2.imread("imgs/mask_05.png")
images = np.array([image1, image2, image3, image4, image5])/255
masks = np.array([mask1[:,:,0], mask2[:,:,0], mask3[:,:,0], mask4[:,:,0], mask5[:,:,0]])/255

# %%
final_image = graph_model.create_final_image(images, masks, 1, 0.01)
plt.imshow(final_image)
